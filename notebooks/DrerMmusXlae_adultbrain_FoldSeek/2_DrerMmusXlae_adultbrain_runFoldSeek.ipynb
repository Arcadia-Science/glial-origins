# %% [markdown]
# # 0. Setup
#
# Import packages and specify any important functions here.

# %%
# import standard python packages
import pandas as pd
import subprocess
import os
import dill
import datetime

# add the utils and env directories to the path
import sys
sys.path.append('../../utils/')
sys.path.append('../../env/')

# import functions from utils directory files
from string_functions import *
from biofile_handling import *

# import paths to software installs from env
from install_locs import *

# %% [markdown]
# # 1. Collect BioFileDockets for each starting dataset
# Collects BioFileDockets for each of the species datasets in the `species_dict`.
#
# This `dict` expects key:value pairs in the form of `species`:`conditions` and is passed to the MultiSpeciesBioFileDocket class, which creates a folder in `output/` for the analysis.
#
# The folder name takes the following format:
#
# - `species_concat` + `_` + `global_conditions` + `analysis_type`
#
# Where `species_concat` is the string concatenation of the alphabetize list of species prefixes.

# %%
################
# general info #
################

species_dict = {
    'Danio_rerio': 'adultbrain',
    'Mus_musculus': 'adultbrain',
    'Xenopus_laevis': 'adultbrain'
}

global_conditions = 'adultbrain'

analysis_type = 'FoldSeek'

################

sample_MSD = MultiSpeciesBioFileDocket(
    species_dict = species_dict,
    global_conditions = global_conditions,
    analysis_type = analysis_type
    )

sample_MSD.make_directory()
sample_MSD.get_BioFileDockets()
sample_MSD.s3_to_local()
# Out:
# file GCF_000002035.5_GRCz10_genomic.gff already exists at ../../output/Drer_adultbrain/GCF_000002035.5_GRCz10_genomic.gff
# file GCF_000002035.5_GRCz10_genomic.fna already exists at ../../output/Drer_adultbrain/GCF_000002035.5_GRCz10_genomic.fna
# file GSM3768152_Brain_8_dge.txt already exists at ../../output/Drer_adultbrain/GSM3768152_Brain_8_dge.txt
# file Drer_adultbrain_uniprot-idmm.tsv already exists at ../../output/Drer_adultbrain/Drer_adultbrain_uniprot-idmm.tsv
# file Drer_adultbrain_gtf-idmm.tsv already exists at ../../output/Drer_adultbrain/Drer_adultbrain_gtf-idmm.tsv
# file GCF_000002035.5_GRCz10_genomic_cDNA.fna already exists at ../../output/Drer_adultbrain/GCF_000002035.5_GRCz10_genomic_cDNA.fna
# file GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.bed already exists at ../../output/Drer_adultbrain/GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.bed
# file GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.cds already exists at ../../output/Drer_adultbrain/GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.cds
# file GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.gff3 already exists at ../../output/Drer_adultbrain/GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.gff3
# file GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.pep already exists at ../../output/Drer_adultbrain/GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.pep
# file GSM3768152_Brain_8_dge_asOrthogroup.txt already exists at ../../output/Drer_adultbrain/GSM3768152_Brain_8_dge_asOrthogroup.txt
# file Drer_adultbrain_og-idmm.tsv already exists at ../../output/Drer_adultbrain/Drer_adultbrain_og-idmm.tsv
# file DrerMmusXlae_adultbrain_Orthogroups.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/OrthoFinder/Results_Sep28/Orthogroups/DrerMmusXlae_adultbrain_Orthogroups.tsv
# file Drer_Exc_top_200DE_Orthogroup_ids.txt already exists at ../../output/Drer_adultbrain/Drer_Exc_top_200DE_Orthogroup_ids.txt
# file Drer_adultbrain_Brain_8_cellannot.tsv already exists at ../../output/Drer_adultbrain/Drer_adultbrain_Brain_8_cellannot.tsv
# file DrerMmusXlae_adultbrain_Orthogroups.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/OrthoFinder/Results_Sep28/Orthogroups/DrerMmusXlae_adultbrain_Orthogroups.tsv
# file DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv
# file Drer_uniprot-taxid_7955_genes.tsv already exists at ../../output/Drer_adultbrain/Drer_uniprot-taxid_7955_genes.tsv
# file Drer_adultbrain_sc-idmm.tsv already exists at ../../output/Drer_adultbrain/Drer_adultbrain_sc-idmm.tsv
# file DrerMmusXlae_adultbrain_struclusters_file.tsv already exists at ../../output/DrerMmusXlae_adultbrain_FoldSeek/DrerMmusXlae_adultbrain_struclusters_file.tsv
# download: s3://arcadia-reference-datasets/organisms/Danio_rerio/functional_sequencing/scRNA-Seq/GSM3768152_Brain_8_dge_asStrucluster.txt to ../../output/Drer_adultbrain/GSM3768152_Brain_8_dge_asStrucluster.txt
# file DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv already exists at ../../output/DrerMmusXlae_adultbrain_FoldSeek/DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv
# file Drer_Exc_top_250DE_StruCluster_ids.txt already exists at ../../output/Drer_adultbrain/Drer_Exc_top_250DE_StruCluster_ids.txt
# file GCF_000001635.23_GRCm38.p3_genomic.gff already exists at ../../output/Mmus_adultbrain/GCF_000001635.23_GRCm38.p3_genomic.gff
# file GCF_000001635.23_GRCm38.p3_genomic.fna already exists at ../../output/Mmus_adultbrain/GCF_000001635.23_GRCm38.p3_genomic.fna
# file GSM2906405_Brain1_dge_coerced.txt already exists at ../../output/Mmus_adultbrain/GSM2906405_Brain1_dge_coerced.txt
# file Mmus_adultbrain_uniprot-idmm.tsv already exists at ../../output/Mmus_adultbrain/Mmus_adultbrain_uniprot-idmm.tsv
# file Mmus_adultbrain_gtf-idmm.tsv already exists at ../../output/Mmus_adultbrain/Mmus_adultbrain_gtf-idmm.tsv
# file GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna already exists at ../../output/Mmus_adultbrain/GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna
# file GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.bed already exists at ../../output/Mmus_adultbrain/GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.bed
# file GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.cds already exists at ../../output/Mmus_adultbrain/GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.cds
# file GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.gff3 already exists at ../../output/Mmus_adultbrain/GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.gff3
# file GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.pep already exists at ../../output/Mmus_adultbrain/GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.pep
# file GSM2906405_Brain1_dge_coerced_asOrthogroup.txt already exists at ../../output/Mmus_adultbrain/GSM2906405_Brain1_dge_coerced_asOrthogroup.txt
# file Mmus_adultbrain_og-idmm.tsv already exists at ../../output/Mmus_adultbrain/Mmus_adultbrain_og-idmm.tsv
# file DrerMmusXlae_adultbrain_Orthogroups.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/OrthoFinder/Results_Sep28/Orthogroups/DrerMmusXlae_adultbrain_Orthogroups.tsv
# file Mmus_Exc_top_200DE_Orthogroup_ids.txt already exists at ../../output/Mmus_adultbrain/Mmus_Exc_top_200DE_Orthogroup_ids.txt
# file Mmus_adultbrain_Brain_1_cellannot.tsv already exists at ../../output/Mmus_adultbrain/Mmus_adultbrain_Brain_1_cellannot.tsv
# file DrerMmusXlae_adultbrain_Orthogroups.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/OrthoFinder/Results_Sep28/Orthogroups/DrerMmusXlae_adultbrain_Orthogroups.tsv
# file DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv
# file Mmus_uniprot-taxid_10090_genes.tsv already exists at ../../output/Mmus_adultbrain/Mmus_uniprot-taxid_10090_genes.tsv
# file Mmus_adultbrain_sc-idmm.tsv already exists at ../../output/Mmus_adultbrain/Mmus_adultbrain_sc-idmm.tsv
# file DrerMmusXlae_adultbrain_struclusters_file.tsv already exists at ../../output/DrerMmusXlae_adultbrain_FoldSeek/DrerMmusXlae_adultbrain_struclusters_file.tsv
# file GSM2906405_Brain1_dge_coerced_asStrucluster.txt already exists at ../../output/Mmus_adultbrain/GSM2906405_Brain1_dge_coerced_asStrucluster.txt
# file Mmus_Exc_top_250DE_StruCluster_ids.txt already exists at ../../output/Mmus_adultbrain/Mmus_Exc_top_250DE_StruCluster_ids.txt
# file DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv already exists at ../../output/DrerMmusXlae_adultbrain_FoldSeek/DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv
# file XENLA_9.2_Xenbase.gtf already exists at ../../output/Xlae_adultbrain/XENLA_9.2_Xenbase.gtf
# file XENLA_9.2_GCA.gff already exists at ../../output/Xlae_adultbrain/XENLA_9.2_GCA.gff
# file XENLA_9.2_genome.fa already exists at ../../output/Xlae_adultbrain/XENLA_9.2_genome.fa
# file GSM6214268_Xenopus_brain_COL65_dge.txt already exists at ../../output/Xlae_adultbrain/GSM6214268_Xenopus_brain_COL65_dge.txt
# file Xlae_adultbrain_uniprot-idmm.tsv already exists at ../../output/Xlae_adultbrain/Xlae_adultbrain_uniprot-idmm.tsv
# file Xlae_adultbrain_gtf-idmm.tsv already exists at ../../output/Xlae_adultbrain/Xlae_adultbrain_gtf-idmm.tsv
# file XENLA_9.2_genome_cDNA.fa already exists at ../../output/Xlae_adultbrain/XENLA_9.2_genome_cDNA.fa
# file XENLA_9.2_genome_cDNA.fa.transdecoder.bed already exists at ../../output/Xlae_adultbrain/XENLA_9.2_genome_cDNA.fa.transdecoder.bed
# file XENLA_9.2_genome_cDNA.fa.transdecoder.cds already exists at ../../output/Xlae_adultbrain/XENLA_9.2_genome_cDNA.fa.transdecoder.cds
# file XENLA_9.2_genome_cDNA.fa.transdecoder.gff3 already exists at ../../output/Xlae_adultbrain/XENLA_9.2_genome_cDNA.fa.transdecoder.gff3
# file XENLA_9.2_genome_cDNA.fa.transdecoder.pep already exists at ../../output/Xlae_adultbrain/XENLA_9.2_genome_cDNA.fa.transdecoder.pep
# file DrerMmusXlae_adultbrain_Orthogroups.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/OrthoFinder/Results_Sep28/Orthogroups/DrerMmusXlae_adultbrain_Orthogroups.tsv
# file GSM6214268_Xenopus_brain_COL65_dge_asOrthogroup.txt already exists at ../../output/Xlae_adultbrain/GSM6214268_Xenopus_brain_COL65_dge_asOrthogroup.txt
# file Xlae_adultbrain_og-idmm.tsv already exists at ../../output/Xlae_adultbrain/Xlae_adultbrain_og-idmm.tsv
# file DrerMmusXlae_adultbrain_Orthogroups.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/OrthoFinder/Results_Sep28/Orthogroups/DrerMmusXlae_adultbrain_Orthogroups.tsv
# file Xlae_adultbrain_Brain3_4_cellannot.tsv already exists at ../../output/Xlae_adultbrain/Xlae_adultbrain_Brain3_4_cellannot.tsv
# file DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv already exists at ../../output/DrerMmusXlae_adultbrain_OrthoFinder/DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv
# file Xlae_uniprot-taxid_8355_genes.tsv already exists at ../../output/Xlae_adultbrain/Xlae_uniprot-taxid_8355_genes.tsv
# file Xlae_adultbrain_sc-idmm.tsv already exists at ../../output/Xlae_adultbrain/Xlae_adultbrain_sc-idmm.tsv
# file DrerMmusXlae_adultbrain_struclusters_file.tsv already exists at ../../output/DrerMmusXlae_adultbrain_FoldSeek/DrerMmusXlae_adultbrain_struclusters_file.tsv
# file GSM6214268_Xenopus_brain_COL65_dge_asStrucluster.txt already exists at ../../output/Xlae_adultbrain/GSM6214268_Xenopus_brain_COL65_dge_asStrucluster.txt
# file Xlae_Exc_top_250DE_StruCluster_ids.txt already exists at ../../output/Xlae_adultbrain/Xlae_Exc_top_250DE_StruCluster_ids.txt
# file Xlae_Exc_top_200DE_Orthogroup_ids.txt already exists at ../../output/Xlae_adultbrain/Xlae_Exc_top_200DE_Orthogroup_ids.txt
# file DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv already exists at ../../output/DrerMmusXlae_adultbrain_FoldSeek/DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv

# %% [markdown]
# # 2. Get gene list from UniProt using Taxid
# Also, set the taxid for each species BioFileDocket.

# %%
taxid_dict = {
    'Drer': 7955,
    'Mmus': 10090,
    'Xlae': 8355
}

for pre in sample_MSD.species_BioFileDockets:
    taxid = taxid_dict[pre]
    sample_MSD.species_BioFileDockets[pre].set_taxid(taxid)
    uniprot_genes = UniProtTaxidListFile(
        sampledict = sample_MSD.SampleDicts[pre],
        taxid = taxid_dict[pre]
    )
    sample_MSD.species_BioFileDockets[pre].add_keyfile(uniprot_genes, 'taxid_genes')
    
    display(pd.read_csv(sample_MSD.species_BioFileDockets[pre].taxid_genes.path, sep = '\t'))
# Out:
#              Entry  Organism (ID)                                     Organism
# 0       A0A068EUV3           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 1       A0A068F1F8           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 2       A0A0B5JK15           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 3       A0A0B5JK91           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 4       A0A0B5JK99           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# ...            ...            ...                                          ...
# 101297      Z4YJ68           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 101298      Z4YJ74           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 101299      Z4YJ80           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 101300      Z4YJ92           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
# 101301      Z4YJA1           7955  Danio rerio (Zebrafish) (Brachydanio rerio)
#
# [101302 rows x 3 columns]
#             Entry  Organism (ID)              Organism
# 0      A0A075F5C6          10090  Mus musculus (Mouse)
# 1      A0A087WPF7          10090  Mus musculus (Mouse)
# 2      A0A087WPT2          10090  Mus musculus (Mouse)
# 3      A0A087WPU4          10090  Mus musculus (Mouse)
# 4      A0A087WRK1          10090  Mus musculus (Mouse)
# ...           ...            ...                   ...
# 88013      Z4YN82          10090  Mus musculus (Mouse)
# 88014      Z4YN86          10090  Mus musculus (Mouse)
# 88015      Z4YN92          10090  Mus musculus (Mouse)
# 88016      Z4YNA3          10090  Mus musculus (Mouse)
# 88017      Z4YNA9          10090  Mus musculus (Mouse)
#
# [88018 rows x 3 columns]
#             Entry  Organism (ID)                              Organism
# 0      A0A191ZDL1           8355  Xenopus laevis (African clawed frog)
# 1      A0A1L8ETL3           8355  Xenopus laevis (African clawed frog)
# 2      A0A1L8F5J9           8355  Xenopus laevis (African clawed frog)
# 3      A0A1L8FGV9           8355  Xenopus laevis (African clawed frog)
# 4      A0A1L8FJZ4           8355  Xenopus laevis (African clawed frog)
# ...           ...            ...                                   ...
# 67298      W8W3P3           8355  Xenopus laevis (African clawed frog)
# 67299      X2FP34           8355  Xenopus laevis (African clawed frog)
# 67300      X5FKY5           8355  Xenopus laevis (African clawed frog)
# 67301      X5FX98           8355  Xenopus laevis (African clawed frog)
# 67302      X5J6M9           8355  Xenopus laevis (African clawed frog)
#
# [67303 rows x 3 columns]

# %% [markdown]
# # 3. Download files from all species into a single directory

# %%
output_folder = sample_MSD.directory
alphafold_folder = output_folder + 'alphafold/'
if not os.path.exists(alphafold_folder):
    os.mkdir(alphafold_folder)

for pre in sample_MSD.species_BioFileDockets:
    taxid = sample_MSD.species_BioFileDockets[pre].taxid
    target_files = 'gs://public-datasets-deepmind-alphafold/proteomes/proteome-tax_id-' + taxid + '-*'
    
    checkpoint_filepath = output_folder + taxid + '.checkpoint'
    
    if not os.path.exists(checkpoint_filepath):
        subprocess.run(['gsutil', '-m', 'cp', target_files, output_folder])
        print('Download and untar for taxid', taxid, 'completed;\ncheckpoint file created at', checkpoint_filepath)
        
        filepaths = [output_folder + file for file in os.listdir(output_folder) if '.tar' in file]
        for file in filepaths:
            # Important to put all of the untar'd files into a separate folder
            # Otherwise filesystem stutters b/c too many files in a single directory
            subprocess.run(['tar', '-xf', file, '--directory', alphafold_folder])
        
        subprocess.run(['touch', checkpoint_filepath])
    else:
        print('Download and untar for taxid', taxid, 'has already been processed at', output_folder)
# Out:
# Download and untar for taxid 7955 has already been processed at ../../output/DrerMmusXlae_adultbrain_FoldSeek/
# Download and untar for taxid 10090 has already been processed at ../../output/DrerMmusXlae_adultbrain_FoldSeek/
# Download and untar for taxid 8355 has already been processed at ../../output/DrerMmusXlae_adultbrain_FoldSeek/

# %%
db_folder = output_folder + 'all_foldomesDB'
foldseek_clustertsv = output_folder + 'clu_greedy.tsv'

if not os.path.exists(foldseek_clustertsv):

    subprocess.run(['foldseek', 'createdb', alphafold_folder, db_folder])

    foldseek_out = output_folder + 'all_by_all'
    foldseek_tmp = output_folder + 'tmp'
    subprocess.run(['foldseek', 'search', db_folder, db_folder, foldseek_out, foldseek_tmp, '-a'])

    foldseek_tmscore = output_folder + 'all_by_all_tmscore'
    subprocess.run(['foldseek', 'aln2tmscore', db_folder, db_folder, foldseek_out, foldseek_tmscore])

    foldseek_tsv = foldseek_tmscore + '.tsv'
    subprocess.run(['foldseek', 'createtsv', db_folder, db_folder, foldseek_tmscore, foldseek_tsv])
    
    foldseek_cluster = output_folder + 'clu'
    subprocess.run(['foldseek', 'clust', db_folder, foldseek_out, foldseek_cluster, '--cluster-mode', '0', '--similarity-type', '2'])
    
    subprocess.run(['foldseek', 'createtsv', db_folder, db_folder, foldseek_cluster, foldseek_clustertsv])

else:
    print('final cluster tsv file already found at', foldseek_clustertsv)
# Out:
# final cluster tsv file already found at ../../output/DrerMmusXlae_adultbrain_FoldSeek/clu_greedy.tsv

# %%
df = pd.read_csv(foldseek_clustertsv, sep = '\t', names = ['ClusterRep', 'uniprot_id'])
df['ClusterRep'] = df['ClusterRep'].str.split('-', expand = True)[1]
df['uniprot_id'] = df['uniprot_id'].str.split('-', expand = True)[1]

df_merged = df.groupby('ClusterRep').agg({i: ('first' if i == 'ClusterRep' else lambda x: [i for i in x]) for i in df.columns}).reset_index(drop = True)
df_merged.drop(columns = ['ClusterRep'], inplace = True)
df_merged.insert(0, 'StruCluster', 'SC' + df_merged.index.astype('str'))

for pre in taxid_dict:
    species_genes = pd.read_csv(sample_MSD.species_BioFileDockets[pre].taxid_genes.path, sep = '\t')
    species_genelist = set(species_genes['Entry'])
    df_merged[pre] = df_merged['uniprot_id'].apply(lambda x: ','.join(set(x).intersection(species_genelist)))

struclusters_df = df_merged.drop(columns = ['uniprot_id'])
struclusters_filename = '_'.join([sample_MSD.species_concat, sample_MSD.global_conditions, 'struclusters_file.tsv'])

struclusters_file = FoldSeekOutputFile(
    filename = struclusters_filename, 
    multispeciesbiofiledocket = sample_MSD,
    directory = sample_MSD.directory)

struclusters_df.to_csv(struclusters_file.path, sep = '\t', index = None)

display(struclusters_df)
# Out:
#       StruCluster                                               Drer  \
# 0             SC0
# 1             SC1  Q4KMH7,E7EXY5,A0A2R8Q696,A0A2R8Q359,A0A2R8Q8V9...
# 2             SC2
# 3             SC3
# 4             SC4
# ...           ...                                                ...
# 36646     SC36646
# 36647     SC36647
# 36648     SC36648                           A0A2R8PWB6,F1QHT1,A5D8S0
# 36649     SC36649
# 36650     SC36650
#
#                                                     Mmus  \
# 0                A0A023NE78,A0A4P2VRD2,B3Y998,A0A023NE65
# 1      Q8VC03,D3Z4J9,Q05BC3,A7ISP9,A0A024A3D6,A0A0R4J...
# 2                                             A0A024CD92
# 3                       A0A024CEZ3,A0A024CD39,A0A024CDU6
# 4
# ...                                                  ...
# 36646                                             Z4YN28
# 36647                                             Z4YN31
# 36648                                      Q3UXL4,Z4YN37
# 36649                                             Z4YN77
# 36650                                             Z4YN82
#
#                                       Xlae
# 0
# 1      Q2TAF3,A0A1L8GJX2,A0A1L8G1A2,Q5U577
# 2
# 3
# 4                               A0A060CJT7
# ...                                    ...
# 36646
# 36647
# 36648                    A1L2H3,A0A1L8G1N3
# 36649
# 36650
#
# [36651 rows x 4 columns]

# %% [markdown]
# # 4. Generate Orthofinder_exc file from gxc file of each starting dataset

# %%
gxc_to_exc(sample_MSD = sample_MSD,
           embedding_df = struclusters_df, 
           exc_file = struclusters_file)
# Out:
# Using StruCluster embeddings as expected from FoldSeek
# StruCluster_excfile already exists at ../../output/Drer_adultbrain/GSM3768152_Brain_8_dge_asStruCluster.txt skipping
# StruCluster_excfile already exists at ../../output/Mmus_adultbrain/GSM2906405_Brain1_dge_coerced_asStruCluster.txt skipping
# StruCluster_excfile already exists at ../../output/Xlae_adultbrain/GSM6214268_Xenopus_brain_COL65_dge_asStruCluster.txt skipping

# %% [markdown]
# # 5. Generate merged exc file for all samples in dataset
#
# (TO BE WRITTEN)

# %%
collector_df = pd.DataFrame()

export_filename = '_'.join([sample_MSD.species_concat, sample_MSD.global_conditions, 'asStruCluster', 'combined_exc.tsv'])

jointexc = JointExcFile(
    multispeciesbiofiledocket = sample_MSD,
    directory = sample_MSD.directory,
    filename = export_filename,
    embedding = 'StruCluster',
    sources = [sample_MSD.species_BioFileDockets[pre].StruCluster_exc for pre in sample_MSD.species_BioFileDockets]
)

if not os.path.exists(jointexc.path):

    # Iterates through all of the species in the Species BioFileDocket
    for i, pre in enumerate(sample_MSD.species_BioFileDockets.keys()):
    
        df = pd.read_csv(sample_MSD.species_BioFileDockets[pre].StruCluster_exc.path, sep = '\t')
        df = df.add_prefix(pre + '_')
        df.rename(columns = {pre + '_' + 'StruCluster': 'StruCluster'}, inplace = True)
    
        if i == 0:
            collector_df = df
        else:
            collector_df = collector_df.merge(df, on = 'StruCluster', how = 'inner')

    collector_df.to_csv(jointexc.path, sep = '\t', index = None)

# Iterates through all of the species in the Species BioFileDocket
for pre in sample_MSD.species_BioFileDockets.keys():
    sample_MSD.species_BioFileDockets[pre].add_keyfile(jointexc, 'StruCluster_jointexc')

# %% [markdown]
# # 6. Pickle the species_BioFileDocket files

# %%
for pre in sample_MSD.species_BioFileDockets.keys():
    sample_MSD.species_BioFileDockets[pre].local_to_s3()
    sample_MSD.species_BioFileDockets[pre].pickle()
    sample_MSD.species_BioFileDockets[pre].push_to_s3(overwrite = True)
# Out:
# GCF_000002035.5_GRCz10_genomic.gff already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000002035.5_GRCz10_genomic.fna already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GSM3768152_Brain_8_dge.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Drer_adultbrain_uniprot-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Drer_adultbrain_gtf-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000002035.5_GRCz10_genomic_cDNA.fna already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.bed already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.cds already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.gff3 already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000002035.5_GRCz10_genomic_cDNA.fna.transdecoder.pep already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GSM3768152_Brain_8_dge_asOrthogroup.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Drer_adultbrain_og-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_Orthogroups.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Drer_Exc_top_200DE_Orthogroup_ids.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Drer_adultbrain_Brain_8_cellannot.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_Orthogroups.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Drer_uniprot-taxid_7955_genes.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# upload: ../../output/Drer_adultbrain/Drer_adultbrain_sc_idmm.tsv to s3://arcadia-reference-datasets/organisms/Danio_rerio/genomics_reference/mapping_file/Drer_adultbrain_sc_idmm.tsv
# DrerMmusXlae_adultbrain_struclusters_file.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Drer_Exc_top_250DE_StruCluster_ids.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# upload: ../../output/Drer_adultbrain/GSM3768152_Brain_8_dge_asStruCluster.txt to s3://arcadia-reference-datasets/organisms/Danio_rerio/functional_sequencing/scRNA-Seq/GSM3768152_Brain_8_dge_asStruCluster.txt
# Drer_adultbrain_sample_BioFileDocket.pkl already exists in S3 bucket; overwriting.
# upload: ../../output/Drer_adultbrain/Drer_adultbrain_sample_BioFileDocket.pkl to s3://arcadia-reference-datasets/glial-origins-pkl/Drer_adultbrain_sample_BioFileDocket.pkl
# GCF_000001635.23_GRCm38.p3_genomic.gff already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000001635.23_GRCm38.p3_genomic.fna already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GSM2906405_Brain1_dge_coerced.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Mmus_adultbrain_uniprot-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Mmus_adultbrain_gtf-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.bed already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.cds already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.gff3 already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GCF_000001635.23_GRCm38.p3_genomic_cDNA.fna.transdecoder.pep already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GSM2906405_Brain1_dge_coerced_asOrthogroup.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Mmus_adultbrain_og-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_Orthogroups.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Mmus_Exc_top_200DE_Orthogroup_ids.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Mmus_adultbrain_Brain_1_cellannot.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_Orthogroups.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Mmus_uniprot-taxid_10090_genes.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# upload: ../../output/Mmus_adultbrain/Mmus_adultbrain_sc_idmm.tsv to s3://arcadia-reference-datasets/organisms/Mus_musculus/genomics_reference/mapping_file/Mmus_adultbrain_sc_idmm.tsv
# DrerMmusXlae_adultbrain_struclusters_file.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# upload: ../../output/Mmus_adultbrain/GSM2906405_Brain1_dge_coerced_asStruCluster.txt to s3://arcadia-reference-datasets/organisms/Mus_musculus/functional_sequencing/scRNA-Seq/GSM2906405_Brain1_dge_coerced_asStruCluster.txt
# Mmus_Exc_top_250DE_StruCluster_ids.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Mmus_adultbrain_sample_BioFileDocket.pkl already exists in S3 bucket; overwriting.
# upload: ../../output/Mmus_adultbrain/Mmus_adultbrain_sample_BioFileDocket.pkl to s3://arcadia-reference-datasets/glial-origins-pkl/Mmus_adultbrain_sample_BioFileDocket.pkl
# XENLA_9.2_Xenbase.gtf already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# XENLA_9.2_GCA.gff already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# XENLA_9.2_genome.fa already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GSM6214268_Xenopus_brain_COL65_dge.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Xlae_adultbrain_uniprot-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Xlae_adultbrain_gtf-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# XENLA_9.2_genome_cDNA.fa already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# XENLA_9.2_genome_cDNA.fa.transdecoder.bed already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# XENLA_9.2_genome_cDNA.fa.transdecoder.cds already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# XENLA_9.2_genome_cDNA.fa.transdecoder.gff3 already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# XENLA_9.2_genome_cDNA.fa.transdecoder.pep already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_Orthogroups.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# GSM6214268_Xenopus_brain_COL65_dge_asOrthogroup.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Xlae_adultbrain_og-idmm.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_Orthogroups.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Xlae_adultbrain_Brain3_4_cellannot.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_asOrthogroup_combined_exc.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Xlae_uniprot-taxid_8355_genes.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# upload: ../../output/Xlae_adultbrain/Xlae_adultbrain_sc_idmm.tsv to s3://arcadia-reference-datasets/organisms/Xenopus_laevis/genomics_reference/mapping_file/Xlae_adultbrain_sc_idmm.tsv
# DrerMmusXlae_adultbrain_struclusters_file.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# upload: ../../output/Xlae_adultbrain/GSM6214268_Xenopus_brain_COL65_dge_asStruCluster.txt to s3://arcadia-reference-datasets/organisms/Xenopus_laevis/functional_sequencing/scRNA-Seq/GSM6214268_Xenopus_brain_COL65_dge_asStruCluster.txt
# Xlae_Exc_top_250DE_StruCluster_ids.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Xlae_Exc_top_200DE_Orthogroup_ids.txt already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# DrerMmusXlae_adultbrain_asStruCluster_combined_exc.tsv already exists in S3 bucket, skipping upload. set overwrite = True to overwrite the existing file.
# Xlae_adultbrain_sample_BioFileDocket.pkl already exists in S3 bucket; overwriting.
# upload: ../../output/Xlae_adultbrain/Xlae_adultbrain_sample_BioFileDocket.pkl to s3://arcadia-reference-datasets/glial-origins-pkl/Xlae_adultbrain_sample_BioFileDocket.pkl
